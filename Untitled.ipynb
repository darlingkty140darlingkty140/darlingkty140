# %%
1+1
# Out:
# 2

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2
)
# Out:
# 1.0

# %%
plot((2,10,3,13,7))

# %%
randn(10)
# Out:
# array([ 0.17742274, -1.41300455,  0.32243581, -0.11388071,  0.25206627,
#         0.46032397, -0.82261401, -1.39392554, -0.49871798, -0.77971082])

# %%
plot(randn(10))
